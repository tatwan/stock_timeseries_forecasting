# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas_datareader.data as web

# %%
strong = ['TSLA', 'ZM', 'MRNA', 'AMZN', 'NFLX', 'NVDA', 'AAPL', 'GME']
poor = ['CCL', 'MRO', 'UAL', 'SLB', 'OKE', 'FARM', 'GLBS']

s_df = web.get_data_alphavantage(strong, api_key='LNXDD4M6P3VUGUWD')
p_df = web.get_data_alphavantage(poor, api_key='LNXDD4M6P3VUGUWD')
sp500 = web.get_data_alphavantage('SPY', api_key='LNXDD4M6P3VUGUWD')

# %%
s_df.tail()
# Out:
#                open    high     low   close    volume
# 2021-06-22  217.730  225.88  209.17  220.40   8200177
# 2021-06-23  221.450  222.57  214.12  219.34   3555090
# 2021-06-24  221.156  227.45  211.60  212.31   3863339
# 2021-06-25  214.000  214.20  198.50  209.51  12692749
# 2021-06-28  211.250  224.45  210.20  213.25   4879364

# %%
s_df.close.plot()
# Out:
# <AxesSubplot:>

# %%
p_df.close.plot()
# Out:
# <AxesSubplot:>

# %%
sp500.close.plot()
# Out:
# <AxesSubplot:>
